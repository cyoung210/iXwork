# %% [markdown]
# # Filtering DataFrames and Series

# %%
import pandas as pd

# %% [markdown]
# We are going to use a dataset that has Airbnb listing information in Lisbon.

# %%
df = pd.read_csv('data/airbnb.csv', index_col='room_id')

# %%
df.shape
# Out:
# (13232, 8)

# %%
df.head()
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 17031      66015  Entire home/apt           Alvalade        0
# 25659     107347  Entire home/apt  Santa Maria Maior       63
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29396     126415  Entire home/apt  Santa Maria Maior      132
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                      5.0             2       1.0   57.0
# 17031                     0.0             2       1.0   46.0
# 25659                     5.0             3       1.0   69.0
# 29248                     4.5             4       1.0   58.0
# 29396                     5.0             4       1.0   67.0

# %% [markdown]
# # Selecting rows

# %% [markdown]
# ## Selecting rows by their position - iloc
#
# We use the function [iloc](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.iloc.html) to select specific rows on a Data Frame (regardless of the index).
#
# With `iloc` we select rows regarding their row number, starting at 0.

# %%
df.iloc[0]
# Out:
# host_id                           14455
# room_type               Entire home/apt
# neighborhood                      Belém
# reviews                               8
# overall_satisfaction                  5
# accommodates                          2
# bedrooms                              1
# price                                57
# Name: 6499, dtype: object

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# If we want the selection to be a dataframe (instead of a Series), we can use double brackets `[[]]`

# %%
df.iloc[[0]]
# Out:
#          host_id        room_type neighborhood  reviews  overall_satisfaction  \
# room_id
# 6499       14455  Entire home/apt        Belém        8                   5.0
#
#          accommodates  bedrooms  price
# room_id
# 6499                2       1.0   57.0

# %% [markdown]
# We can select multiple rows at once:

# %%
df.iloc[[0, 3,5]]
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29720     128075  Entire home/apt            Estrela       14
#
#          overall_satisfaction  accommodates  bedrooms   price
# room_id
# 6499                      5.0             2       1.0    57.0
# 29248                     4.5             4       1.0    58.0
# 29720                     5.0            16       9.0  1154.0

# %% [markdown]
# Or use slices like with arrays:

# %%
df.iloc[2:10]
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 25659     107347  Entire home/apt  Santa Maria Maior       63
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29396     126415  Entire home/apt  Santa Maria Maior      132
# 29720     128075  Entire home/apt            Estrela       14
# 29872     128698  Entire home/apt          Alcântara       25
# 29891     128792  Entire home/apt       Misericórdia       28
# 29915     128890  Entire home/apt     Avenidas Novas       28
# 33312     144398  Entire home/apt       Misericórdia       24
#
#          overall_satisfaction  accommodates  bedrooms   price
# room_id
# 25659                     5.0             3       1.0    69.0
# 29248                     4.5             4       1.0    58.0
# 29396                     5.0             4       1.0    67.0
# 29720                     5.0            16       9.0  1154.0
# 29872                     5.0             2       1.0    75.0
# 29891                     5.0             3       1.0    49.0
# 29915                     4.5             3       1.0    58.0
# 33312                     4.5             4       1.0    66.0

# %% [markdown]
# ## Selecting rows by their index value - loc
#
# * With [.loc](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.loc.html) we can select rows based on their index value.

# %% [markdown]
# Since we have set the dataframe index as the Airbnb listing, we can select a specific room based on its id, for example, the listing 10186098.

# %%
df.loc[10186098]
# Out:
# host_id                            520897
# room_type                 Entire home/apt
# neighborhood            Santa Maria Maior
# reviews                                 2
# overall_satisfaction                    0
# accommodates                            4
# bedrooms                                1
# price                                  64
# Name: 10186098, dtype: object

# %% [markdown]
# Selecting an index value that doesnt exist wil fail like it would do with a dictionary

# %%
df.loc[[5]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-1f76c38f71f1> in <module>
# ----> 1 df.loc[[5]]
#
# ~/anaconda3/envs/data/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~/anaconda3/envs/data/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1900                     raise ValueError('Cannot index with multidimensional key')
#    1901
# -> 1902                 return self._getitem_iterable(key, axis=axis)
#    1903
#    1904             # nested tuple slicing
#
# ~/anaconda3/envs/data/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1203             # A collection of keys
#    1204             keyarr, indexer = self._get_listlike_indexer(key, axis,
# -> 1205                                                          raise_missing=False)
#    1206             return self.obj._reindex_with_indexers({axis: [keyarr, indexer]},
#    1207                                                    copy=True, allow_dups=True)
#
# ~/anaconda3/envs/data/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~/anaconda3/envs/data/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Int64Index([5], dtype='int64', name='room_id')] are in the [index]"

# %% [markdown]
# Same as with .iloc, we can select multiple values at once.

# %%
df.loc[[29872, 19188572, 4612503 ]]
# Out:
#             host_id        room_type       neighborhood  reviews  \
# room_id
# 29872        128698  Entire home/apt          Alcântara       25
# 19188572  134216988     Private room            Arroios        0
# 4612503    22078192  Entire home/apt  Santa Maria Maior       12
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 29872                      5.0             2       1.0   75.0
# 19188572                   0.0             4       1.0   58.0
# 4612503                    5.0             3       1.0  113.0

# %% [markdown]
# We can use a boolean array (a list of True and False) to select multiple rows with loc, this is called a **mask**.

# %%
df.loc[[True, True, False, True]]
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 17031      66015  Entire home/apt           Alvalade        0
# 29248     125768  Entire home/apt  Santa Maria Maior      225
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                      5.0             2       1.0   57.0
# 17031                     0.0             2       1.0   46.0
# 29248                     4.5             4       1.0   58.0

# %% [markdown]
# We see we have selected rows 1,2 and 4 of the dataframe

# %%
df.head()
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 17031      66015  Entire home/apt           Alvalade        0
# 25659     107347  Entire home/apt  Santa Maria Maior       63
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29396     126415  Entire home/apt  Santa Maria Maior      132
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                      5.0             2       1.0   57.0
# 17031                     0.0             2       1.0   46.0
# 25659                     5.0             3       1.0   69.0
# 29248                     4.5             4       1.0   58.0
# 29396                     5.0             4       1.0   67.0

# %% [markdown]
# ## Column Selection

# %% [markdown]
# ## Selecting columns by their name

# %% [markdown]
# We can select columns using dot notation **(as long as the column names dont have spaces or non alphanumerical characters on them)**

# %%
df.room_type
# Out:
# room_id
# 6499        Entire home/apt
# 17031       Entire home/apt
# 25659       Entire home/apt
# 29248       Entire home/apt
# 29396       Entire home/apt
# 29720       Entire home/apt
# 29872       Entire home/apt
# 29891       Entire home/apt
# 29915       Entire home/apt
# 33312       Entire home/apt
# 33348          Private room
# 34783          Private room
# 34977       Entire home/apt
# 40817       Entire home/apt
# 42172       Entire home/apt
# 42519       Entire home/apt
# 44043       Entire home/apt
# 46567          Private room
# 47717       Entire home/apt
# 50108       Entire home/apt
# 55116          Private room
# 56906       Entire home/apt
# 57850       Entire home/apt
# 59227       Entire home/apt
# 65553       Entire home/apt
# 65878       Entire home/apt
# 72807          Private room
# 73764       Entire home/apt
# 75171       Entire home/apt
# 77130       Entire home/apt
#                  ...
# 19360001       Private room
# 19361749    Entire home/apt
# 19362076    Entire home/apt
# 19362417       Private room
# 19363100       Private room
# 19368183    Entire home/apt
# 19369538    Entire home/apt
# 19370050    Entire home/apt
# 19370165    Entire home/apt
# 19370278    Entire home/apt
# 19370578    Entire home/apt
# 19370769    Entire home/apt
# 19373212    Entire home/apt
# 19376122    Entire home/apt
# 19379554    Entire home/apt
# 19379856    Entire home/apt
# 19380177    Entire home/apt
# 19380414    Entire home/apt
# 19380457    Entire home/apt
# 19381136    Entire home/apt
# 19383103    Entire home/apt
# 19383615    Entire home/apt
# 19385945    Entire home/apt
# 19386235    Entire home/apt
# 19386898    Entire home/apt
# 19388006    Entire home/apt
# 19393935    Entire home/apt
# 19396300    Entire home/apt
# 19397373    Entire home/apt
# 19400722    Entire home/apt
# Name: room_type, Length: 13232, dtype: object

# %% [markdown]
# Which is the same as doing:

# %%
df['room_type']
# Out:
# room_id
# 6499        Entire home/apt
# 17031       Entire home/apt
# 25659       Entire home/apt
# 29248       Entire home/apt
# 29396       Entire home/apt
# 29720       Entire home/apt
# 29872       Entire home/apt
# 29891       Entire home/apt
# 29915       Entire home/apt
# 33312       Entire home/apt
# 33348          Private room
# 34783          Private room
# 34977       Entire home/apt
# 40817       Entire home/apt
# 42172       Entire home/apt
# 42519       Entire home/apt
# 44043       Entire home/apt
# 46567          Private room
# 47717       Entire home/apt
# 50108       Entire home/apt
# 55116          Private room
# 56906       Entire home/apt
# 57850       Entire home/apt
# 59227       Entire home/apt
# 65553       Entire home/apt
# 65878       Entire home/apt
# 72807          Private room
# 73764       Entire home/apt
# 75171       Entire home/apt
# 77130       Entire home/apt
#                  ...
# 19360001       Private room
# 19361749    Entire home/apt
# 19362076    Entire home/apt
# 19362417       Private room
# 19363100       Private room
# 19368183    Entire home/apt
# 19369538    Entire home/apt
# 19370050    Entire home/apt
# 19370165    Entire home/apt
# 19370278    Entire home/apt
# 19370578    Entire home/apt
# 19370769    Entire home/apt
# 19373212    Entire home/apt
# 19376122    Entire home/apt
# 19379554    Entire home/apt
# 19379856    Entire home/apt
# 19380177    Entire home/apt
# 19380414    Entire home/apt
# 19380457    Entire home/apt
# 19381136    Entire home/apt
# 19383103    Entire home/apt
# 19383615    Entire home/apt
# 19385945    Entire home/apt
# 19386235    Entire home/apt
# 19386898    Entire home/apt
# 19388006    Entire home/apt
# 19393935    Entire home/apt
# 19396300    Entire home/apt
# 19397373    Entire home/apt
# 19400722    Entire home/apt
# Name: room_type, Length: 13232, dtype: object

# %% [markdown]
# When we select one column we receive a pd.Series, we can use double brackets to select multiple columns (if we select multiple columns we will always receive a dataframe).

# %%
df[["room_type", "price"]].head()
# Out:
#                room_type  price
# room_id
# 6499     Entire home/apt   57.0
# 17031    Entire home/apt   46.0
# 25659    Entire home/apt   69.0
# 29248    Entire home/apt   58.0
# 29396    Entire home/apt   67.0

# %% [markdown]
# We can always select columns with loc

# %%
df.loc[:, "room_type"][:10]
# Out:
# room_id
# 6499     Entire home/apt
# 17031    Entire home/apt
# 25659    Entire home/apt
# 29248    Entire home/apt
# 29396    Entire home/apt
# 29720    Entire home/apt
# 29872    Entire home/apt
# 29891    Entire home/apt
# 29915    Entire home/apt
# 33312    Entire home/apt
# Name: room_type, dtype: object

# %% [markdown]
# The index doesnt have to be unique, for example we can set the neighbourhood as the index.

# %%
df.head()
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 17031      66015  Entire home/apt           Alvalade        0
# 25659     107347  Entire home/apt  Santa Maria Maior       63
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29396     126415  Entire home/apt  Santa Maria Maior      132
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                      5.0             2       1.0   57.0
# 17031                     0.0             2       1.0   46.0
# 25659                     5.0             3       1.0   69.0
# 29248                     4.5             4       1.0   58.0
# 29396                     5.0             4       1.0   67.0

# %%
df = df.set_index("neighborhood")

# %%
df.loc["Belém"].head()
# Out:
#               host_id        room_type  reviews  overall_satisfaction  \
# neighborhood
# Belém           14455  Entire home/apt        8                   5.0
# Belém          992647  Entire home/apt       54                   4.0
# Belém         2083563     Private room        2                   0.0
# Belém         2341627  Entire home/apt       64                   4.5
# Belém         3168004  Entire home/apt       57                   4.5
#
#               accommodates  bedrooms  price
# neighborhood
# Belém                    2       1.0   57.0
# Belém                    2       1.0   45.0
# Belém                    2       1.0  127.0
# Belém                    4       1.0   67.0
# Belém                    3       2.0   46.0

# %% [markdown]
# We set back the index to `host_id`, we need to use the argument `drop=False` so pandas doesnt remove the original index

# %%
df = df.set_index("host_id", drop=False)

# %% [markdown]
# ## Mask

# %% [markdown]
# The function ([Mask](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.mask.html)) allows us to "hide" parts of a dataframe that match a certain condition.

# %%
df.mask(df.overall_satisfaction == 5.0)
# Out:
#                host_id        room_type  reviews  overall_satisfaction  \
# host_id
# 14455              NaN              NaN      NaN                   NaN
# 66015          66015.0  Entire home/apt      0.0                   0.0
# 107347             NaN              NaN      NaN                   NaN
# 125768        125768.0  Entire home/apt    225.0                   4.5
# 126415             NaN              NaN      NaN                   NaN
# 128075             NaN              NaN      NaN                   NaN
# 128698             NaN              NaN      NaN                   NaN
# 128792             NaN              NaN      NaN                   NaN
# 128890        128890.0  Entire home/apt     28.0                   4.5
# 144398        144398.0  Entire home/apt     24.0                   4.5
# 144484        144484.0     Private room      2.0                   0.0
# 149980        149980.0     Private room      0.0                   0.0
# 146695        146695.0  Entire home/apt     54.0                   4.5
# 176410        176410.0  Entire home/apt    229.0                   4.5
# 184400        184400.0  Entire home/apt     45.0                   4.5
# 136230        136230.0  Entire home/apt     79.0                   4.5
# 192830             NaN              NaN      NaN                   NaN
# 208343             NaN              NaN      NaN                   NaN
# 217058        217058.0  Entire home/apt     70.0                   4.5
# 229376        229376.0  Entire home/apt     33.0                   4.5
# 259744        259744.0     Private room      1.0                   0.0
# 270457        270457.0  Entire home/apt     86.0                   4.5
# 276092        276092.0  Entire home/apt     52.0                   4.5
# 184400        184400.0  Entire home/apt     25.0                   4.5
# 320407        320407.0  Entire home/apt    102.0                   4.5
# 322145             NaN              NaN      NaN                   NaN
# 378525        378525.0     Private room      1.0                   0.0
# 154341        154341.0  Entire home/apt     18.0                   4.5
# 184400        184400.0  Entire home/apt     19.0                   4.5
# 412702        412702.0  Entire home/apt     74.0                   4.5
# ...                ...              ...      ...                   ...
# 26864642    26864642.0     Private room      0.0                   0.0
# 127589264  127589264.0  Entire home/apt      0.0                   0.0
# 88928860    88928860.0  Entire home/apt      0.0                   0.0
# 28225140    28225140.0     Private room      0.0                   0.0
# 88928860    88928860.0     Private room      0.0                   0.0
# 14317794    14317794.0  Entire home/apt      0.0                   0.0
# 114388582  114388582.0  Entire home/apt      0.0                   0.0
# 14317794    14317794.0  Entire home/apt      0.0                   0.0
# 114388582  114388582.0  Entire home/apt      0.0                   0.0
# 135784989  135784989.0  Entire home/apt      0.0                   0.0
# 131185696  131185696.0  Entire home/apt      0.0                   0.0
# 135787783  135787783.0  Entire home/apt      0.0                   0.0
# 131185696  131185696.0  Entire home/apt      0.0                   0.0
# 119457178  119457178.0  Entire home/apt      0.0                   0.0
# 104083974  104083974.0  Entire home/apt      0.0                   0.0
# 12723358    12723358.0  Entire home/apt      0.0                   0.0
# 104083974  104083974.0  Entire home/apt      0.0                   0.0
# 85047832    85047832.0  Entire home/apt      0.0                   0.0
# 104083974  104083974.0  Entire home/apt      0.0                   0.0
# 131185696  131185696.0  Entire home/apt      0.0                   0.0
# 48844725    48844725.0  Entire home/apt      0.0                   0.0
# 100924999  100924999.0  Entire home/apt      0.0                   0.0
# 135895465  135895465.0  Entire home/apt      0.0                   0.0
# 55922649    55922649.0  Entire home/apt      0.0                   0.0
# 95929866    95929866.0  Entire home/apt      0.0                   0.0
# 135915593  135915593.0  Entire home/apt      0.0                   0.0
# 5376796      5376796.0  Entire home/apt      0.0                   0.0
# 6115933      6115933.0  Entire home/apt      0.0                   0.0
# 97139334    97139334.0  Entire home/apt      0.0                   0.0
# 28219108    28219108.0  Entire home/apt      0.0                   0.0
#
#            accommodates  bedrooms  price
# host_id
# 14455               NaN       NaN    NaN
# 66015               2.0       1.0   46.0
# 107347              NaN       NaN    NaN
# 125768              4.0       1.0   58.0
# 126415              NaN       NaN    NaN
# 128075              NaN       NaN    NaN
# 128698              NaN       NaN    NaN
# 128792              NaN       NaN    NaN
# 128890              3.0       1.0   58.0
# 144398              4.0       1.0   66.0
# 144484              6.0       1.0   46.0
# 149980              1.0       1.0   54.0
# 146695              6.0       2.0   60.0
# 176410              2.0       1.0   52.0
# 184400              6.0       2.0  138.0
# 136230              3.0       1.0   87.0
# 192830              NaN       NaN    NaN
# 208343              NaN       NaN    NaN
# 217058              3.0       1.0   57.0
# 229376              4.0       1.0   69.0
# 259744              2.0       2.0   68.0
# 270457              3.0       1.0   52.0
# 276092              3.0       2.0   70.0
# 184400              7.0       3.0  138.0
# 320407              2.0       1.0   58.0
# 322145              NaN       NaN    NaN
# 378525              1.0       1.0   29.0
# 154341              2.0       1.0   64.0
# 184400              5.0       2.0  115.0
# 412702              3.0       0.0   52.0
# ...                 ...       ...    ...
# 26864642            6.0       3.0   33.0
# 127589264           4.0       2.0   69.0
# 88928860            4.0       2.0  104.0
# 28225140            2.0       1.0   29.0
# 88928860            2.0       1.0   46.0
# 14317794            4.0       1.0  104.0
# 114388582           4.0       2.0   65.0
# 14317794            3.0       2.0  109.0
# 114388582           4.0       2.0   58.0
# 135784989           4.0       2.0  184.0
# 131185696           5.0       2.0   71.0
# 135787783           4.0       2.0  176.0
# 131185696           4.0       2.0   75.0
# 119457178           5.0       2.0   64.0
# 104083974           4.0       1.0   69.0
# 12723358            2.0       1.0   80.0
# 104083974           6.0       2.0   69.0
# 85047832            2.0       0.0   52.0
# 104083974           6.0       3.0   93.0
# 131185696           3.0       1.0   48.0
# 48844725            4.0       2.0   84.0
# 100924999           4.0       1.0   52.0
# 135895465           4.0       2.0   64.0
# 55922649            4.0       1.0   87.0
# 95929866            3.0       1.0   91.0
# 135915593           6.0       3.0  415.0
# 5376796             3.0       1.0   50.0
# 6115933             6.0       4.0  138.0
# 97139334            4.0       1.0   56.0
# 28219108            5.0       3.0   75.0
#
# [13232 rows x 7 columns]

# %% [markdown]
# We see that the rows that dont match the condition appear as `NaN`, which stands for **Not a Number**, a standard way of saying *"there is no relevant data here"*. Pandas will usually ignore the NaNs.

# %% [markdown]
# ## Where

# %% [markdown]
# On the other hand, [where](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.where.html) hides those rows that don't match the condition (where is the opposite of mask).

# %%
df.where(df.overall_satisfaction == 5.0)

#you can use the any or all functions to allow for multiple conditions
# Out:
#             host_id        room_type  reviews  overall_satisfaction  \
# host_id
# 14455       14455.0  Entire home/apt      8.0                   5.0
# 66015           NaN              NaN      NaN                   NaN
# 107347     107347.0  Entire home/apt     63.0                   5.0
# 125768          NaN              NaN      NaN                   NaN
# 126415     126415.0  Entire home/apt    132.0                   5.0
# 128075     128075.0  Entire home/apt     14.0                   5.0
# 128698     128698.0  Entire home/apt     25.0                   5.0
# 128792     128792.0  Entire home/apt     28.0                   5.0
# 128890          NaN              NaN      NaN                   NaN
# 144398          NaN              NaN      NaN                   NaN
# 144484          NaN              NaN      NaN                   NaN
# 149980          NaN              NaN      NaN                   NaN
# 146695          NaN              NaN      NaN                   NaN
# 176410          NaN              NaN      NaN                   NaN
# 184400          NaN              NaN      NaN                   NaN
# 136230          NaN              NaN      NaN                   NaN
# 192830     192830.0  Entire home/apt    316.0                   5.0
# 208343     208343.0     Private room      3.0                   5.0
# 217058          NaN              NaN      NaN                   NaN
# 229376          NaN              NaN      NaN                   NaN
# 259744          NaN              NaN      NaN                   NaN
# 270457          NaN              NaN      NaN                   NaN
# 276092          NaN              NaN      NaN                   NaN
# 184400          NaN              NaN      NaN                   NaN
# 320407          NaN              NaN      NaN                   NaN
# 322145     322145.0  Entire home/apt     51.0                   5.0
# 378525          NaN              NaN      NaN                   NaN
# 154341          NaN              NaN      NaN                   NaN
# 184400          NaN              NaN      NaN                   NaN
# 412702          NaN              NaN      NaN                   NaN
# ...             ...              ...      ...                   ...
# 26864642        NaN              NaN      NaN                   NaN
# 127589264       NaN              NaN      NaN                   NaN
# 88928860        NaN              NaN      NaN                   NaN
# 28225140        NaN              NaN      NaN                   NaN
# 88928860        NaN              NaN      NaN                   NaN
# 14317794        NaN              NaN      NaN                   NaN
# 114388582       NaN              NaN      NaN                   NaN
# 14317794        NaN              NaN      NaN                   NaN
# 114388582       NaN              NaN      NaN                   NaN
# 135784989       NaN              NaN      NaN                   NaN
# 131185696       NaN              NaN      NaN                   NaN
# 135787783       NaN              NaN      NaN                   NaN
# 131185696       NaN              NaN      NaN                   NaN
# 119457178       NaN              NaN      NaN                   NaN
# 104083974       NaN              NaN      NaN                   NaN
# 12723358        NaN              NaN      NaN                   NaN
# 104083974       NaN              NaN      NaN                   NaN
# 85047832        NaN              NaN      NaN                   NaN
# 104083974       NaN              NaN      NaN                   NaN
# 131185696       NaN              NaN      NaN                   NaN
# 48844725        NaN              NaN      NaN                   NaN
# 100924999       NaN              NaN      NaN                   NaN
# 135895465       NaN              NaN      NaN                   NaN
# 55922649        NaN              NaN      NaN                   NaN
# 95929866        NaN              NaN      NaN                   NaN
# 135915593       NaN              NaN      NaN                   NaN
# 5376796         NaN              NaN      NaN                   NaN
# 6115933         NaN              NaN      NaN                   NaN
# 97139334        NaN              NaN      NaN                   NaN
# 28219108        NaN              NaN      NaN                   NaN
#
#            accommodates  bedrooms   price
# host_id
# 14455               2.0       1.0    57.0
# 66015               NaN       NaN     NaN
# 107347              3.0       1.0    69.0
# 125768              NaN       NaN     NaN
# 126415              4.0       1.0    67.0
# 128075             16.0       9.0  1154.0
# 128698              2.0       1.0    75.0
# 128792              3.0       1.0    49.0
# 128890              NaN       NaN     NaN
# 144398              NaN       NaN     NaN
# 144484              NaN       NaN     NaN
# 149980              NaN       NaN     NaN
# 146695              NaN       NaN     NaN
# 176410              NaN       NaN     NaN
# 184400              NaN       NaN     NaN
# 136230              NaN       NaN     NaN
# 192830              7.0       3.0    80.0
# 208343              2.0       1.0    39.0
# 217058              NaN       NaN     NaN
# 229376              NaN       NaN     NaN
# 259744              NaN       NaN     NaN
# 270457              NaN       NaN     NaN
# 276092              NaN       NaN     NaN
# 184400              NaN       NaN     NaN
# 320407              NaN       NaN     NaN
# 322145              4.0       1.0    76.0
# 378525              NaN       NaN     NaN
# 154341              NaN       NaN     NaN
# 184400              NaN       NaN     NaN
# 412702              NaN       NaN     NaN
# ...                 ...       ...     ...
# 26864642            NaN       NaN     NaN
# 127589264           NaN       NaN     NaN
# 88928860            NaN       NaN     NaN
# 28225140            NaN       NaN     NaN
# 88928860            NaN       NaN     NaN
# 14317794            NaN       NaN     NaN
# 114388582           NaN       NaN     NaN
# 14317794            NaN       NaN     NaN
# 114388582           NaN       NaN     NaN
# 135784989           NaN       NaN     NaN
# 131185696           NaN       NaN     NaN
# 135787783           NaN       NaN     NaN
# 131185696           NaN       NaN     NaN
# 119457178           NaN       NaN     NaN
# 104083974           NaN       NaN     NaN
# 12723358            NaN       NaN     NaN
# 104083974           NaN       NaN     NaN
# 85047832            NaN       NaN     NaN
# 104083974           NaN       NaN     NaN
# 131185696           NaN       NaN     NaN
# 48844725            NaN       NaN     NaN
# 100924999           NaN       NaN     NaN
# 135895465           NaN       NaN     NaN
# 55922649            NaN       NaN     NaN
# 95929866            NaN       NaN     NaN
# 135915593           NaN       NaN     NaN
# 5376796             NaN       NaN     NaN
# 6115933             NaN       NaN     NaN
# 97139334            NaN       NaN     NaN
# 28219108            NaN       NaN     NaN
#
# [13232 rows x 7 columns]

# %% [markdown]
# # Filtering with []

# %% [markdown]
# We can also filter by using brackets.
# The difference between filtering with brackets and using `mask/where` is that with brackets we only receive a segment of the dataframe (less rows), while with `mask/where` we receive a dataframe with the same rows and index than the original one.

# %% [markdown]
# For example, we can filter the dataframe to see all the listings in `Belem`:

# %%
df = pd.read_csv('data/airbnb.csv', index_col='room_id')

# %%
df.head()
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 17031      66015  Entire home/apt           Alvalade        0
# 25659     107347  Entire home/apt  Santa Maria Maior       63
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29396     126415  Entire home/apt  Santa Maria Maior      132
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                      5.0             2       1.0   57.0
# 17031                     0.0             2       1.0   46.0
# 25659                     5.0             3       1.0   69.0
# 29248                     4.5             4       1.0   58.0
# 29396                     5.0             4       1.0   67.0

# %%
df.where(df.neighborhood=="Belém").shape
# Out:
# (13232, 8)

# %% [markdown]
# If we use brackets, the dataframe we get is smaller

# %%
df[df.neighborhood == 'Belém']
# Out:
#             host_id        room_type neighborhood  reviews  \
# room_id
# 6499          14455  Entire home/apt        Belém        8
# 202654       992647  Entire home/apt        Belém       54
# 418945      2083563     Private room        Belém        2
# 472183      2341627  Entire home/apt        Belém       64
# 635674      3168004  Entire home/apt        Belém       57
# 758927      3999677  Entire home/apt        Belém       10
# 783766      4132746     Private room        Belém       49
# 787134      3634413  Entire home/apt        Belém       48
# 820798      1756107  Entire home/apt        Belém        4
# 862418      4520597  Entire home/apt        Belém       84
# 935478      1029524  Entire home/apt        Belém       33
# 964480      3168004  Entire home/apt        Belém       60
# 977488      3680667  Entire home/apt        Belém       15
# 1175357     2644971  Entire home/apt        Belém       32
# 1327544     7204661     Private room        Belém        2
# 1378048     3634413  Entire home/apt        Belém       47
# 1427168     7649262     Private room        Belém       10
# 1506789     8048828  Entire home/apt        Belém      122
# 1550751     4132746  Entire home/apt        Belém       40
# 1724077     8810620  Entire home/apt        Belém      105
# 1725052     8810620  Entire home/apt        Belém      104
# 1803927     9456814  Entire home/apt        Belém        0
# 2127428     8810620  Entire home/apt        Belém       17
# 2487363    12123730  Entire home/apt        Belém       72
# 2590441    10766652  Entire home/apt        Belém       89
# 2608025     9456814  Entire home/apt        Belém        0
# 2612285    11926451     Private room        Belém       23
# 2623665     2990770  Entire home/apt        Belém       44
# 2623683      776635  Entire home/apt        Belém        7
# 2699381     8911887  Entire home/apt        Belém        1
# ...             ...              ...          ...      ...
# 18213525   19254511  Entire home/apt        Belém        0
# 18227246  125892685  Entire home/apt        Belém        1
# 18260651   37385021  Entire home/apt        Belém       11
# 18271919  125011727  Entire home/apt        Belém        2
# 18317275    9618517     Private room        Belém        0
# 18461428  115620308     Private room        Belém        2
# 18476060  115620308     Private room        Belém        2
# 18476206  115620308     Private room        Belém        0
# 18483915    2528842  Entire home/apt        Belém        0
# 18512183     651801  Entire home/apt        Belém        0
# 18561077    3695889     Private room        Belém        0
# 18578066  128986153  Entire home/apt        Belém        4
# 18702996   72308704  Entire home/apt        Belém        0
# 18735274  128909464  Entire home/apt        Belém        2
# 18745670  121873936  Entire home/apt        Belém        1
# 18892988   25020268  Entire home/apt        Belém        0
# 18928035   39219982  Entire home/apt        Belém        0
# 18965299   10463670  Entire home/apt        Belém        0
# 18969850    1185103  Entire home/apt        Belém        3
# 18998643  132541338  Entire home/apt        Belém        0
# 19034170   62521369  Entire home/apt        Belém        5
# 19036207  132541338  Entire home/apt        Belém        0
# 19228230  134610991  Entire home/apt        Belém        0
# 19260440   48194126     Private room        Belém        0
# 19269358   53334020  Entire home/apt        Belém        0
# 19282613    1343572  Entire home/apt        Belém        0
# 19285913  130280879  Entire home/apt        Belém        0
# 19379554  104083974  Entire home/apt        Belém        0
# 19380177  104083974  Entire home/apt        Belém        0
# 19380457  104083974  Entire home/apt        Belém        0
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                       5.0             2       1.0   57.0
# 202654                     4.0             2       1.0   45.0
# 418945                     0.0             2       1.0  127.0
# 472183                     4.5             4       1.0   67.0
# 635674                     4.5             3       2.0   46.0
# 758927                     5.0             4       2.0   69.0
# 783766                     4.5             3       1.0   22.0
# 787134                     4.0             5       3.0   58.0
# 820798                     4.5             4       1.0   68.0
# 862418                     4.5             4       1.0   46.0
# 935478                     4.5             4       1.0   46.0
# 964480                     4.5             4       2.0   52.0
# 977488                     5.0             4       1.0   69.0
# 1175357                    5.0             3       2.0   55.0
# 1327544                    0.0             2       1.0  144.0
# 1378048                    4.5             7       3.0   87.0
# 1427168                    5.0             2       1.0   49.0
# 1506789                    5.0             4       1.0   58.0
# 1550751                    4.5             8       3.0   44.0
# 1724077                    4.5             4       2.0   64.0
# 1725052                    4.5             5       3.0   64.0
# 1803927                    0.0             6       3.0  173.0
# 2127428                    5.0             9       5.0  184.0
# 2487363                    4.5             6       2.0   52.0
# 2590441                    5.0             4       2.0   75.0
# 2608025                    0.0            10       2.0  288.0
# 2612285                    4.0             2       1.0   18.0
# 2623665                    5.0             2       1.0   68.0
# 2623683                    5.0            10       3.0  115.0
# 2699381                    0.0             4       1.0   78.0
# ...                        ...           ...       ...    ...
# 18213525                   0.0             2       1.0   85.0
# 18227246                   0.0             4       2.0   79.0
# 18260651                   4.5             4       1.0   29.0
# 18271919                   0.0             4       1.0   46.0
# 18317275                   0.0             3       1.0   87.0
# 18461428                   0.0            10       2.0  208.0
# 18476060                   0.0             5       0.0   93.0
# 18476206                   0.0             5       0.0   84.0
# 18483915                   0.0             2       1.0   91.0
# 18512183                   0.0             4       1.0   53.0
# 18561077                   0.0             2       1.0   58.0
# 18578066                   5.0             4       1.0   58.0
# 18702996                   0.0             3       1.0   58.0
# 18735274                   0.0             5       3.0   52.0
# 18745670                   0.0             3       1.0   41.0
# 18892988                   0.0             3       1.0   58.0
# 18928035                   0.0             4       2.0   80.0
# 18965299                   0.0             4       1.0  138.0
# 18969850                   4.5             6       2.0   68.0
# 18998643                   0.0             6       2.0  126.0
# 19034170                   5.0             4       1.0   85.0
# 19036207                   0.0             4       1.0   97.0
# 19228230                   0.0             3       0.0   80.0
# 19260440                   0.0             2       1.0   27.0
# 19269358                   0.0             4       1.0   75.0
# 19282613                   0.0             3       2.0   93.0
# 19285913                   0.0             6       2.0   68.0
# 19379554                   0.0             4       1.0   69.0
# 19380177                   0.0             6       2.0   69.0
# 19380457                   0.0             6       3.0   93.0
#
# [254 rows x 8 columns]

# %%
df[df.neighborhood == 'Belém'].shape
# Out:
# (254, 8)

# %% [markdown]
# We can select the inverse of a condition if we put `~` in front of it.
#
# For example, to select all listings that are not in Belem, we can do this:

# %%
df[~(df.neighborhood ==  "Belém")].shape
# Out:
# (12978, 8)

# %% [markdown]
# # Multiple Selection
#
# We can filter a dataframe based on multiple conditions.

# %% [markdown]
# We can select rows that match multiple conditions by concatenating the conditions with `&`.
#
# For example, if we want those listings in Belém with more than 3 bedrooms:

# %%
df[(df.neighborhood == 'Belém') & (df.bedrooms > 3)]
# Out:
#             host_id        room_type neighborhood  reviews  \
# room_id
# 2127428     8810620  Entire home/apt        Belém       17
# 5737018    29744618  Entire home/apt        Belém       46
# 6884183    11926451  Entire home/apt        Belém        1
# 9522737    46064752  Entire home/apt        Belém       27
# 15272166   17263208  Entire home/apt        Belém        1
# 17228964  101182323  Entire home/apt        Belém        2
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 2127428                    5.0             9       5.0  184.0
# 5737018                    4.5            10       4.0  128.0
# 6884183                    0.0            10       5.0  138.0
# 9522737                    5.0             8       4.0   78.0
# 15272166                   0.0             6       4.0  288.0
# 17228964                   0.0            16       7.0  260.0

# %% [markdown]
# Same way, we can select rows that match one condition OR the other with the pipe (`|`)

# %%
df[(df.neighborhood == "Belém") | (df.neighborhood == "Benfica")]
# Out:
#             host_id        room_type neighborhood  reviews  \
# room_id
# 6499          14455  Entire home/apt        Belém        8
# 202654       992647  Entire home/apt        Belém       54
# 212915      1097919     Private room      Benfica        0
# 418945      2083563     Private room        Belém        2
# 472183      2341627  Entire home/apt        Belém       64
# 573313      2820083  Entire home/apt      Benfica       12
# 635674      3168004  Entire home/apt        Belém       57
# 758927      3999677  Entire home/apt        Belém       10
# 783766      4132746     Private room        Belém       49
# 787134      3634413  Entire home/apt        Belém       48
# 820798      1756107  Entire home/apt        Belém        4
# 862418      4520597  Entire home/apt        Belém       84
# 889052      1951343     Private room      Benfica        0
# 935478      1029524  Entire home/apt        Belém       33
# 964480      3168004  Entire home/apt        Belém       60
# 977488      3680667  Entire home/apt        Belém       15
# 1175357     2644971  Entire home/apt        Belém       32
# 1327544     7204661     Private room        Belém        2
# 1378048     3634413  Entire home/apt        Belém       47
# 1427168     7649262     Private room        Belém       10
# 1506789     8048828  Entire home/apt        Belém      122
# 1550751     4132746  Entire home/apt        Belém       40
# 1573223     8178431  Entire home/apt      Benfica       17
# 1670147     6362620     Private room      Benfica       32
# 1724077     8810620  Entire home/apt        Belém      105
# 1725052     8810620  Entire home/apt        Belém      104
# 1803927     9456814  Entire home/apt        Belém        0
# 2127428     8810620  Entire home/apt        Belém       17
# 2399414    12260436     Private room      Benfica        1
# 2487363    12123730  Entire home/apt        Belém       72
# ...             ...              ...          ...      ...
# 18476206  115620308     Private room        Belém        0
# 18483915    2528842  Entire home/apt        Belém        0
# 18512183     651801  Entire home/apt        Belém        0
# 18517941  128538019  Entire home/apt      Benfica        0
# 18561077    3695889     Private room        Belém        0
# 18578066  128986153  Entire home/apt        Belém        4
# 18702996   72308704  Entire home/apt        Belém        0
# 18705665   50870971     Private room      Benfica        6
# 18735274  128909464  Entire home/apt        Belém        2
# 18745670  121873936  Entire home/apt        Belém        1
# 18879061   78574742     Private room      Benfica        3
# 18892988   25020268  Entire home/apt        Belém        0
# 18922110   33111699  Entire home/apt      Benfica        0
# 18928035   39219982  Entire home/apt        Belém        0
# 18965299   10463670  Entire home/apt        Belém        0
# 18969850    1185103  Entire home/apt        Belém        3
# 18998643  132541338  Entire home/apt        Belém        0
# 19034170   62521369  Entire home/apt        Belém        5
# 19036207  132541338  Entire home/apt        Belém        0
# 19113703  129744959  Entire home/apt      Benfica        0
# 19147754  133878061     Private room      Benfica        0
# 19228230  134610991  Entire home/apt        Belém        0
# 19260440   48194126     Private room        Belém        0
# 19269358   53334020  Entire home/apt        Belém        0
# 19282613    1343572  Entire home/apt        Belém        0
# 19285913  130280879  Entire home/apt        Belém        0
# 19299623   71859210  Entire home/apt      Benfica        0
# 19379554  104083974  Entire home/apt        Belém        0
# 19380177  104083974  Entire home/apt        Belém        0
# 19380457  104083974  Entire home/apt        Belém        0
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                       5.0             2       1.0   57.0
# 202654                     4.0             2       1.0   45.0
# 212915                     0.0             6       1.0   93.0
# 418945                     0.0             2       1.0  127.0
# 472183                     4.5             4       1.0   67.0
# 573313                     4.5             4       2.0   74.0
# 635674                     4.5             3       2.0   46.0
# 758927                     5.0             4       2.0   69.0
# 783766                     4.5             3       1.0   22.0
# 787134                     4.0             5       3.0   58.0
# 820798                     4.5             4       1.0   68.0
# 862418                     4.5             4       1.0   46.0
# 889052                     0.0             1       1.0   29.0
# 935478                     4.5             4       1.0   46.0
# 964480                     4.5             4       2.0   52.0
# 977488                     5.0             4       1.0   69.0
# 1175357                    5.0             3       2.0   55.0
# 1327544                    0.0             2       1.0  144.0
# 1378048                    4.5             7       3.0   87.0
# 1427168                    5.0             2       1.0   49.0
# 1506789                    5.0             4       1.0   58.0
# 1550751                    4.5             8       3.0   44.0
# 1573223                    4.5             4       2.0   64.0
# 1670147                    4.5             6       1.0   46.0
# 1724077                    4.5             4       2.0   64.0
# 1725052                    4.5             5       3.0   64.0
# 1803927                    0.0             6       3.0  173.0
# 2127428                    5.0             9       5.0  184.0
# 2399414                    0.0             2       1.0   23.0
# 2487363                    4.5             6       2.0   52.0
# ...                        ...           ...       ...    ...
# 18476206                   0.0             5       0.0   84.0
# 18483915                   0.0             2       1.0   91.0
# 18512183                   0.0             4       1.0   53.0
# 18517941                   0.0             3       1.0   52.0
# 18561077                   0.0             2       1.0   58.0
# 18578066                   5.0             4       1.0   58.0
# 18702996                   0.0             3       1.0   58.0
# 18705665                   5.0             2       1.0   23.0
# 18735274                   0.0             5       3.0   52.0
# 18745670                   0.0             3       1.0   41.0
# 18879061                   5.0             2       1.0   18.0
# 18892988                   0.0             3       1.0   58.0
# 18922110                   0.0             3       2.0   46.0
# 18928035                   0.0             4       2.0   80.0
# 18965299                   0.0             4       1.0  138.0
# 18969850                   4.5             6       2.0   68.0
# 18998643                   0.0             6       2.0  126.0
# 19034170                   5.0             4       1.0   85.0
# 19036207                   0.0             4       1.0   97.0
# 19113703                   0.0             6       3.0  357.0
# 19147754                   0.0            16       5.0   58.0
# 19228230                   0.0             3       0.0   80.0
# 19260440                   0.0             2       1.0   27.0
# 19269358                   0.0             4       1.0   75.0
# 19282613                   0.0             3       2.0   93.0
# 19285913                   0.0             6       2.0   68.0
# 19299623                   0.0             5       2.0  102.0
# 19379554                   0.0             4       1.0   69.0
# 19380177                   0.0             6       2.0   69.0
# 19380457                   0.0             6       3.0   93.0
#
# [325 rows x 8 columns]

# %% [markdown]
# ## Isnull/Notnull
#
# Sometimes we simple want to select those rows there there are no null (`NaN`) values.

# %% [markdown]
# We can select rows where a column is null by doing `column.isnull()`.

# %%
df[df.overall_satisfaction.isnull()]
# Out:
#             host_id        room_type       neighborhood  reviews  \
# room_id
# 1424459     7665008  Entire home/apt       Misericórdia       63
# 3112523    15814568  Entire home/apt       Misericórdia        1
# 4460918     6317960  Entire home/apt            Arroios       75
# 5569600    24291881  Entire home/apt       Misericórdia      151
# 10257022   52731804  Entire home/apt  Santa Maria Maior       21
# 10413859   53629861  Entire home/apt            Arroios       70
# 11255567   56974375  Entire home/apt            Arroios        8
# 15963308   55556833  Entire home/apt      Santo António        0
# 17848221  119340757  Entire home/apt       Misericórdia        1
# 19225610   62988799  Entire home/apt       Misericórdia        0
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 1424459                    NaN             8       4.0  104.0
# 3112523                    NaN             3       1.0   69.0
# 4460918                    NaN             4       1.0   40.0
# 5569600                    NaN             4       2.0   45.0
# 10257022                   NaN             2       0.0   46.0
# 10413859                   NaN             4       1.0   58.0
# 11255567                   NaN             2       1.0   52.0
# 15963308                   NaN             3       2.0   97.0
# 17848221                   NaN             4       1.0   45.0
# 19225610                   NaN             2       0.0   74.0

# %% [markdown]
# Likewise, we can select those rows where a column is not null by using `notnull()`.

# %%
df[df.overall_satisfaction.notnull()].head()
# Out:
#          host_id        room_type       neighborhood  reviews  \
# room_id
# 6499       14455  Entire home/apt              Belém        8
# 17031      66015  Entire home/apt           Alvalade        0
# 25659     107347  Entire home/apt  Santa Maria Maior       63
# 29248     125768  Entire home/apt  Santa Maria Maior      225
# 29396     126415  Entire home/apt  Santa Maria Maior      132
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                      5.0             2       1.0   57.0
# 17031                     0.0             2       1.0   46.0
# 25659                     5.0             3       1.0   69.0
# 29248                     4.5             4       1.0   58.0
# 29396                     5.0             4       1.0   67.0

# %% [markdown]
# An easy way to check if any column has null values is by using `df.notnull().all()` (all will return True only if all rows match the condition:

# %%
df.notnull().all()
# Out:
# host_id                  True
# room_type                True
# neighborhood             True
# reviews                  True
# overall_satisfaction    False
# accommodates             True
# bedrooms                 True
# price                    True
# dtype: bool

# %% [markdown]
# So we see that the column overall_satisfaction has some null values on it

# %% [markdown]
# We can find those rows that have any null like this (any returns true if any value is true, and using axis=1 means we are checking rows instead of columns:

# %%
df[df.isnull().any(axis=1)]
# Out:
#             host_id        room_type       neighborhood  reviews  \
# room_id
# 1424459     7665008  Entire home/apt       Misericórdia       63
# 3112523    15814568  Entire home/apt       Misericórdia        1
# 4460918     6317960  Entire home/apt            Arroios       75
# 5569600    24291881  Entire home/apt       Misericórdia      151
# 10257022   52731804  Entire home/apt  Santa Maria Maior       21
# 10413859   53629861  Entire home/apt            Arroios       70
# 11255567   56974375  Entire home/apt            Arroios        8
# 15963308   55556833  Entire home/apt      Santo António        0
# 17848221  119340757  Entire home/apt       Misericórdia        1
# 19225610   62988799  Entire home/apt       Misericórdia        0
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 1424459                    NaN             8       4.0  104.0
# 3112523                    NaN             3       1.0   69.0
# 4460918                    NaN             4       1.0   40.0
# 5569600                    NaN             4       2.0   45.0
# 10257022                   NaN             2       0.0   46.0
# 10413859                   NaN             4       1.0   58.0
# 11255567                   NaN             2       1.0   52.0
# 15963308                   NaN             3       2.0   97.0
# 17848221                   NaN             4       1.0   45.0
# 19225610                   NaN             2       0.0   74.0

# %% [markdown]
# # Isin

# %% [markdown]
# We can check if an element belongs to a python list like this:

# %%
"potato" in ["potato", "tomato", "lettuce"]
# Out:
# True

# %% [markdown]
# We can use a similar approach with pandas dataframes using `.isin`. For example, if we want to select those listings where the neighborhood is in a specific list we can do it like this:

# %%
favorite_neighbourhoods = ["Belém", "Parque das Nações"]

listings_i_like = df[df.neighborhood.isin(favorite_neighbourhoods)]

listings_i_like.head()
# Out:
#            host_id        room_type       neighborhood  reviews  \
# room_id
# 6499         14455  Entire home/apt              Belém        8
# 105962   106839925  Entire home/apt  Parque das Nações       29
# 129822      639944     Private room  Parque das Nações       50
# 137434      671930  Entire home/apt  Parque das Nações        0
# 184888      887175  Entire home/apt  Parque das Nações        7
#
#          overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499                      5.0             2       1.0   57.0
# 105962                    5.0             4       1.0   69.0
# 129822                    4.5             2       1.0   55.0
# 137434                    0.0             6       2.0  138.0
# 184888                    4.5             6       2.0  115.0

# %% [markdown]
# # Query

# %% [markdown]
# The method `.query` allows us to use SQL to select rows from a dataframe.

# %%
df.query("neighborhood=='Belém' and price>150")
# Out:
#             host_id        room_type neighborhood  reviews  \
# room_id
# 1803927     9456814  Entire home/apt        Belém        0
# 2127428     8810620  Entire home/apt        Belém       17
# 2608025     9456814  Entire home/apt        Belém        0
# 2945967     2083563  Entire home/apt        Belém        1
# 2993599    15262252     Private room        Belém        0
# 3024528    15263699  Entire home/apt        Belém        0
# 3473364     3953109  Entire home/apt        Belém        0
# 3566413     3455184  Entire home/apt        Belém        5
# 4101878    21277737  Entire home/apt        Belém        0
# 5245908     5776233  Entire home/apt        Belém       14
# 5622549    29144581  Entire home/apt        Belém        0
# 7773383    40890592  Entire home/apt        Belém       27
# 14711737    6316416  Entire home/apt        Belém        1
# 15235859   96857687  Entire home/apt        Belém        0
# 15272166   17263208  Entire home/apt        Belém        1
# 15556702  100150750  Entire home/apt        Belém        0
# 17228964  101182323  Entire home/apt        Belém        2
# 18461428  115620308     Private room        Belém        2
#
#           overall_satisfaction  accommodates  bedrooms  price
# room_id
# 1803927                    0.0             6       3.0  173.0
# 2127428                    5.0             9       5.0  184.0
# 2608025                    0.0            10       2.0  288.0
# 2945967                    0.0             2       1.0  202.0
# 2993599                    0.0             2       1.0  404.0
# 3024528                    0.0             4       2.0  692.0
# 3473364                    0.0             5       3.0  209.0
# 3566413                    5.0             6       3.0  173.0
# 4101878                    0.0             4       2.0  230.0
# 5245908                    5.0             4       1.0  173.0
# 5622549                    0.0             2       1.0  230.0
# 7773383                    4.5             6       3.0  173.0
# 14711737                   0.0             4       2.0  173.0
# 15235859                   0.0             3       1.0  231.0
# 15272166                   0.0             6       4.0  288.0
# 15556702                   0.0             4       2.0  231.0
# 17228964                   0.0            16       7.0  260.0
# 18461428                   0.0            10       2.0  208.0

# %% [markdown]
# ## Filtering based on datatypes

# %%
df.dtypes
# Out:
# host_id                   int64
# room_type                object
# neighborhood             object
# reviews                   int64
# overall_satisfaction    float64
# accommodates              int64
# bedrooms                float64
# price                   float64
# dtype: object

# %% [markdown]
# We can use the method `select_dtypes` to select those columns that have specific types.
#
# For example, if we want to select only the columns that are floats, we can do:

# %%
df.select_dtypes(include=[float]).head()
# Out:
#          overall_satisfaction  bedrooms  price
# room_id
# 6499                      5.0       1.0   57.0
# 17031                     0.0       1.0   46.0
# 25659                     5.0       1.0   69.0
# 29248                     4.5       1.0   58.0
# 29396                     5.0       1.0   67.0

# %% [markdown]
# We can also use the parameter `exclude` to filter excluding certain data types.
#
# For example, if we want to exclude those columns that are python objects (and strings are objects), we can do so like:

# %%
df.select_dtypes(exclude=[object]).head()
# Out:
#          host_id  reviews  overall_satisfaction  accommodates  bedrooms  price
# room_id
# 6499       14455        8                   5.0             2       1.0   57.0
# 17031      66015        0                   0.0             2       1.0   46.0
# 25659     107347       63                   5.0             3       1.0   69.0
# 29248     125768      225                   4.5             4       1.0   58.0
# 29396     126415      132                   5.0             4       1.0   67.0
